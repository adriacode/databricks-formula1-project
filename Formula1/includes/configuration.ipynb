# %%
raw_folder_path = "abfss://raw@formula1dl2026c.dfs.core.windows.net"
processed_folder_path = "abfss://processed@formula1dl2026c.dfs.core.windows.net"
presentation_folder_path = "abfss://presentation@formula1dl2026c.dfs.core.windows.net"
